# %%
from pyspark.sql import SparkSession

# Create Spark session
spark = SparkSession.builder \
    .appName("First Spark Application") \   # Give your Spark app a name
    .master("local[*]") \     # Use all cores on your local machine
    .getOrCreate()            # Creates a new session or gets existing one
# Out:
#   Cell In[1], line 5
#     .appName("First Spark Application") \   # Give your Spark app a name
#                                                                         ^
# SyntaxError: unexpected character after line continuation character

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("First Spark Application") \
    .master("local[*]") \
    .getOrCreate()
