# %%
2+2
# Out:
# 4

# %% [markdown]
# this is a markdown cell notes for me

# %%
x = "string"

# %%
x.upper()
# Out:
# 'STRING'

# %%
type(1.2)
# Out:
# float

# %%
type(82)
# Out:
# int

# %%
2+3*5*5
# Out:
# 77

# %%
(2+3)*(5+5)
# Out:
# 50

# %%
type("double")
# Out:
# str

# %%
"i don't like"
# Out:
# "i don't like"

# %%
print("First: {x} Second {y}".format("cow","goat"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print("First: {x} Second {y}".format("cow","goat"))
#
# KeyError: 'x'

# %%
x = "cow"
y = "goat"

print(f"First: {x} Second {y}")
# Out:
# First: cow Second goat

# %%
[1,2,3,4]
# Out:
# [1, 2, 3, 4]

# %%
mylist =["a","b","c"]

# %%
mylist[1]
# Out:
# 'b'

# %%
 mylist.append("d")

# %%
print(mylist)
# Out:
# ['a', 'b', 'c', 'd']

# %%
d ={"country":"Uganda", "Name": "Bernard"}
d["country"]
# Out:
# 'Uganda'

# %%
isAvailable = True

# %%
{1,1,1,2,2,3,4,4,4,5,6,6,5}
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
1>4
# Out:
# False

# %%
7>2
# Out:
# True

# %%
"a" == "a"
# Out:
# True

# %%
1 != 2
# Out:
# True

# %%
(1 == 1)
# Out:
# True

# %%
("a" == "A")
# Out:
# False

# %%
(1 == 1) and ("a" == "a")
# Out:
# True

# %%
(1 == 1) and ("a" == "A")
# Out:
# False

# %%
if(1 == 1):
    print("YEEEESS")
# Out:
# YEEEESS

# %%
seq = [1,2,3,4,5]

for item in seq:
    print(item * 2)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
i = 1
while i < 5:
    print(f"i is {i}")
    i = i + 1
# Out:
# i is 1
# i is 2
# i is 3
# i is 4

# %%
print(list(range(0,5)))
# Out:
# [0, 1, 2, 3, 4]

# %%
for x in range(5):
    print("hi")
# Out:
# hi
# hi
# hi
# hi
# hi

# %%
xl = [1,2,3,4,5]
out = []
for num in xl:
    out.append(num**2)

print(out)
# Out:
# [1, 4, 9, 16, 25]

# %%
def my_func():
    print("hello")
my_func()
# Out:
# hello

# %%
def my_func2(name="NO NAME"):
    print("hello " + name)
my_func2()
# Out:
# hello NO NAME

# %%
st = "hello my name is Sammy"

# %%
st.lower()
# Out:
# 'hello my name is sammy'

# %%
st.upper()
# Out:
# 'HELLO MY NAME IS SAMMY'

# %%
st.split()
# Out:
# ['hello', 'my', 'name', 'is', 'Sammy']
